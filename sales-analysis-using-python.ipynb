# %%
import pandas as pd
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/laibaanwer/superstore-sales-dataset/SuperStoreOrders.csv

# %%
import pandas as pd
df=pd.read_csv("/kaggle/input/datasets/laibaanwer/superstore-sales-dataset/SuperStoreOrders.csv")
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail(40)
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 51250    IN-2014-78228  31-12-2014    6/1/2015  Standard Class
# 51251   MX-2014-122511  31-12-2014    5/1/2015  Standard Class
# 51252     OD-2014-9490  31-12-2014    5/1/2015  Standard Class
# 51253     AO-2014-7730  31-12-2014    4/1/2015  Standard Class
# 51254   MX-2014-158827  31-12-2014    2/1/2015     First Class
# 51255     RS-2014-1460  31-12-2014    2/1/2015    Second Class
# 51256   CA-2014-143259  31-12-2014    4/1/2015  Standard Class
# 51257   CA-2014-126221  31-12-2014    6/1/2015  Standard Class
# 51258     UP-2014-3330  31-12-2014    2/1/2015     First Class
# 51259   MX-2014-116267  31-12-2014    3/1/2015    Second Class
# 51260   CA-2014-143259  31-12-2014    4/1/2015  Standard Class
# 51261   MX-2014-116267  31-12-2014    3/1/2015    Second Class
# 51262     TZ-2014-8350  31-12-2014    3/1/2015     First Class
# 51263   MX-2014-110527  31-12-2014    2/1/2015    Second Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %% [markdown]
# #Information of dataset

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.groupby("category")["sales"].sum().idxmax()
# Out:
# 'Office Supplies'

# %%
df.groupby("region")["profit"].sum().idxmax()
# Out:
# 'Central'

# %%
df.groupby("region")["sales"].sum().idxmax()
# Out:
# 'EMEA'

# %%
df.groupby("category")["profit"].sum().idxmax()
# Out:
# 'Technology'

# %%
df["profit"].mean()
# Out:
# np.float64(28.641739545330474)

# %%
df["sales"].dtype
# Out:
# dtype('O')

# %%
df["sales"]=pd.to_numeric(df["sales"],errors="coerce")

# %%
df["sales"].sum()
# Out:
# np.float64(7835128.0)

# %%
df["customer_name"].head()
# Out:
# 0    Toby Braunhardt
# 1        Joseph Holt
# 2      Annie Thurman
# 3       Eugene Moren
# 4        Joseph Holt
# Name: customer_name, dtype: object

# %%
df.groupby("customer_name")["order_id"].count().idxmax()
# Out:
# 'Muhammed Yedwab'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
category_sales=df.groupby("category")["profit"].sum().reset_index()
plt.figure(figsize=(6,4))
sns.barplot(x="category",y="profit",data=category_sales,color="blue")
plt.title("Total profit by category")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="category",y="discount",data=df,color="green")
plt.title("Total discount by category")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.lineplot(x="category",y="quantity",data=df)
plt.title("Total quantity by category")
plt.show()

# %% [markdown]
# # SuperStore Sales Analysis
#
# ## Objective
# Analyze sales performance across categories and identify business insights using Python, Pandas, and Seaborn.
